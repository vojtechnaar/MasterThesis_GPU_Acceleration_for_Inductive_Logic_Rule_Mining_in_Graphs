# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -lah /content/drive/MyDrive/MasterThesis/MasterThesis/Rewritten_CPP
# Out:
# ls: cannot access '/content/drive/MyDrive/MasterThesis/Rewritten_CPP': No such file or directory

# %%
# %cd /content/drive/MyDrive/MasterThesis/MasterThesis/Rewritten_CPP
# Out:
# /content/drive/MyDrive/MasterThesis/MasterThesis/Rewritten_CPP

# %%
# !sudo apt-get update
# !sudo apt-get install -y libraptor2-dev
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,901 kB]
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,941 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,170 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,794 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,615 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,303 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,839 kB]
# Fetched 31.0 MB in 4s (7,092 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libcurl4-gnutls-dev libraptor2-0 libxslt1-dev libyajl-dev libyajl2
#   raptor2-utils
# Suggested packages:
#   libcurl4-doc libgnutls28-dev libidn11-dev libldap2-dev librtmp-dev
#   libraptor2-doc
# The following packages will be REMOVED:
#   libcurl4-openssl-dev
# The following NEW packages will be installed:
#   libcurl4-gnutls-dev libraptor2-0 libraptor2-dev libxslt1-dev libyajl-dev
#   libyajl2 raptor2-utils
# 0 upgraded, 7 newly installed, 1 to remove and 15 not upgraded.
# Need to get 1,056 kB of archives.
# After this operation, 3,669 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4-gnutls-dev amd64 7.81.0-1ubuntu1.23 [380 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl2 amd64 2.1.0-3ubuntu0.22.04.1 [21.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4.1 [172 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxslt1-dev amd64 1.1.34-4ubuntu0.22.04.5 [219 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl-dev amd64 2.1.0-3ubuntu0.22.04.1 [28.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraptor2-dev amd64 2.0.15-0ubuntu4.1 [221 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 raptor2-utils amd64 2.0.15-0ubuntu4.1 [14.5 kB]
# Fetched 1,056 kB in 1s (814 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 7.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# dpkg: libcurl4-openssl-dev:amd64: dependency problems, but removing anyway as you requested:
#  libhdf5-dev depends on libcurl4-openssl-dev | libcurl-dev; however:
#   Package libcurl4-openssl-dev:amd64 is to be removed.
#   Package libcurl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-dev is to be removed.
#  libhdf5-dev depends on libcurl4-openssl-dev | libcurl-dev; however:
#   Package libcurl4-openssl-dev:amd64 is to be removed.
#   Package libcurl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-dev is to be removed.
#  libproj-dev:amd64 depends on libcurl4-gnutls-dev | libcurl-ssl-dev; however:
#   Package libcurl4-gnutls-dev is not installed.
#   Package libcurl-ssl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-ssl-dev is to be removed.
#  libnetcdf-dev depends on libcurl4-gnutls-dev | libcurl-ssl-dev; however:
#   Package libcurl4-gnutls-dev is not installed.
#   Package libcurl-ssl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-ssl-dev is to be removed.
#  libgdal-dev depends on libcurl4-gnutls-dev | libcurl-ssl-dev; however:
#   Package libcurl4-gnutls-dev is not installed.
#   Package libcurl-ssl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-ssl-dev is to be removed.
#
# (Reading database ... 118194 files and directories currently installed.)
# Removing libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.23) ...
# Selecting previously unselected package libcurl4-gnutls-dev:amd64.
# (Reading database ... 118173 files and directories currently installed.)
# Preparing to unpack .../0-libcurl4-gnutls-dev_7.81.0-1ubuntu1.23_amd64.deb ...
# Unpacking libcurl4-gnutls-dev:amd64 (7.81.0-1ubuntu1.23) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../1-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../2-libraptor2-0_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Selecting previously unselected package libxslt1-dev:amd64.
# Preparing to unpack .../3-libxslt1-dev_1.1.34-4ubuntu0.22.04.5_amd64.deb ...
# Unpacking libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.5) ...
# Selecting previously unselected package libyajl-dev:amd64.
# Preparing to unpack .../4-libyajl-dev_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl-dev:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-dev.
# Preparing to unpack .../5-libraptor2-dev_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking libraptor2-dev (2.0.15-0ubuntu4.1) ...
# Selecting previously unselected package raptor2-utils.
# Preparing to unpack .../6-raptor2-utils_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking raptor2-utils (2.0.15-0ubuntu4.1) ...
# Setting up libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.5) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libcurl4-gnutls-dev:amd64 (7.81.0-1ubuntu1.23) ...
# Setting up libyajl-dev:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Setting up raptor2-utils (2.0.15-0ubuntu4.1) ...
# Setting up libraptor2-dev (2.0.15-0ubuntu4.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link

# %%
# !g++ -std=c++17 main.cpp RdfIndexes.cpp FinalRule.cpp SupportCounting.cpp RuleParser.cpp $(pkg-config --cflags --libs raptor2) -O2 -o rdf_rules_test

# %%
# !ls -lah
# Out:
# total 168K
# -rw------- 1 root root 1.3K Mar 23 16:22 FinalRule.cpp
# -rw------- 1 root root 1.1K Mar 23 16:22 FinalRule.hpp
# -rw------- 1 root root 4.4K Mar 22 11:12 main.cpp
# -rw------- 1 root root 5.0K Mar 23 16:22 RdfIndexes.cpp
# -rw------- 1 root root 1.3K Mar 23 16:22 RdfIndexes.hpp
# -rwx------ 1 root root 114K Mar 23 20:47 rdf_rules_test
# -rw------- 1 root root 6.1K Mar 22 11:06 RuleParser.cpp
# -rw------- 1 root root  780 Mar 22 11:06 RuleParser.hpp
# -rw------- 1 root root  15K Mar 23 20:46 RunCode.ipynb
# -rw------- 1 root root  14K Mar 23 16:22 SupportCounting.cpp
# -rw------- 1 root root 3.3K Mar 23 16:22 SupportCounting.hpp

# %%
# !./rdf_rules_test ../test_data/original_train.ttl ../test_data/rules_150minutes.txt
# Out:
# === Index built ===
# Triples: 6794977
# Unique RDF terms: 3164825
# Predicates in PSO: 26
# Predicates in POS: 26
#
# === Rules loaded ===
# Rule count: 736
#
# Rule 1: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 2 ms
#
# Rule 2: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 118 ms
#
# Rule 3: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 110 ms
#
# Rule 4: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?1 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 9582, HeadCoverage: 0.0776254, HeadSupport: 123439, HeadSize: 123439, Time: 150 ms
#
# Rule 5: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) => ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 4504, HeadCoverage: 0.0381436, HeadSupport: 118080, HeadSize: 118080, Time: 158 ms
#
# Rule 6: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 22917, HeadCoverage: 0.19408, HeadSupport: 118080, HeadSize: 118080, Time: 176 ms
#
# Rule 7: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?1 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 21732, HeadCoverage: 0.185718, HeadSupport: 117016, HeadSize: 117016, Time: 239 ms
#
# Rule 8: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 4504, HeadCoverage: 0.0325084, HeadSupport: 138549, HeadSize: 138549, Time: 179 ms
#
# Rule 9: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 22917, HeadCoverage: 0.193508, HeadSupport: 118429, HeadSize: 118429, Time: 162 ms
#
# Rule 10: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) | Support: 9, HeadCoverage: 0.0422535, HeadSupport: 213, HeadSize: 213, Time: 0 ms
#
# Rule 11: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?2 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) | Support: 9, HeadCoverage: 0.0422535, HeadSupport: 213, HeadSize: 213, Time: 0 ms
#
# Rule 12: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) | Support: 213, HeadCoverage: 1, HeadSupport: 213, HeadSize: 213, Time: 0 ms
#
# Rule 13: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?1 ) | Support: 106, HeadCoverage: 0.946429, HeadSupport: 112, HeadSize: 112, Time: 0 ms
#
# Rule 14: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) | Support: 98, HeadCoverage: 0.875, HeadSupport: 112, HeadSize: 112, Time: 0 ms
#
# Rule 15: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 15, HeadCoverage: 0.0141243, HeadSupport: 1062, HeadSize: 1062, Time: 3 ms
#
# Rule 16: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 3 ms
#
# Rule 17: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 2 ms
#
# Rule 18: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 4 ms
#
# Rule 19: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 3 ms
#
# Rule 20: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 68, HeadCoverage: 0.0640301, HeadSupport: 1062, HeadSize: 1062, Time: 7 ms
#
# Rule 21: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 3 ms
#
# Rule 22: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 209, HeadCoverage: 0.196798, HeadSupport: 1062, HeadSize: 1062, Time: 10 ms
#
# Rule 23: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 62, HeadCoverage: 0.0583804, HeadSupport: 1062, HeadSize: 1062, Time: 20 ms
#
# Rule 24: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 263, HeadCoverage: 0.247646, HeadSupport: 1062, HeadSize: 1062, Time: 29 ms
#
# Rule 25: ( ?0 https://w3id.org/biolink/vocab/assesses ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/capable_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) | Support: 94, HeadCoverage: 0.839286, HeadSupport: 112, HeadSize: 112, Time: 16 ms
#
# Rule 26: ( ?0 https://w3id.org/biolink/vocab/enabled_by ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?1 ) | Support: 423, HeadCoverage: 0.0553955, HeadSupport: 7636, HeadSize: 7636, Time: 17 ms
#
# Rule 27: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/enables ?1 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?0 ) | Support: 3747, HeadCoverage: 0.490702, HeadSupport: 7636, HeadSize: 7636, Time: 26 ms
#
# Rule 28: ( ?0 https://w3id.org/biolink/vocab/enabled_by ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?1 ) | Support: 209, HeadCoverage: 0.0273704, HeadSupport: 7636, HeadSize: 7636, Time: 28 ms
#
# Rule 29: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 15054, HeadCoverage: 0.298946, HeadSupport: 50357, HeadSize: 50357, Time: 110 ms
#
# Rule 30: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?0 ) | Support: 624, HeadCoverage: 0.0240462, HeadSupport: 25950, HeadSize: 25950, Time: 89 ms
#
# Rule 31: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/occurs_in ?2 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 13229, HeadCoverage: 0.262704, HeadSupport: 50357, HeadSize: 50357, Time: 159 ms
#
# Rule 32: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?1 ) | Support: 6833, HeadCoverage: 0.263314, HeadSupport: 25950, HeadSize: 25950, Time: 107 ms
#
# Rule 33: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?1 ) | Support: 1279, HeadCoverage: 0.0492871, HeadSupport: 25950, HeadSize: 25950, Time: 507 ms
#
# Rule 34: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/produces ?1 ) | Support: 217, HeadCoverage: 0.0621242, HeadSupport: 3493, HeadSize: 3493, Time: 12 ms
#
# Rule 35: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/produces ?1 ) | Support: 162, HeadCoverage: 0.0463785, HeadSupport: 3493, HeadSize: 3493, Time: 121 ms
#
# Rule 36: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) | Support: 3102, HeadCoverage: 0.0933353, HeadSupport: 33235, HeadSize: 33235, Time: 210 ms
#
# Rule 37: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) | Support: 995, HeadCoverage: 0.0299383, HeadSupport: 33235, HeadSize: 33235, Time: 233 ms
#
# Rule 38: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?1 ) | Support: 1528, HeadCoverage: 0.0459756, HeadSupport: 33235, HeadSize: 33235, Time: 103 ms
#
# Rule 39: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 3609, HeadCoverage: 0.0451905, HeadSupport: 79862, HeadSize: 79862, Time: 162 ms
#
# Rule 40: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?1 ) | Support: 1347, HeadCoverage: 0.0405296, HeadSupport: 33235, HeadSize: 33235, Time: 896 ms
#
# Rule 41: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?0 ) | Support: 1322, HeadCoverage: 0.0165536, HeadSupport: 79862, HeadSize: 79862, Time: 321 ms
#
# Rule 42: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 1341, HeadCoverage: 0.0167915, HeadSupport: 79862, HeadSize: 79862, Time: 315 ms
#
# Rule 43: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 3609, HeadCoverage: 0.0451905, HeadSupport: 79862, HeadSize: 79862, Time: 177 ms
#
# Rule 44: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 12185, HeadCoverage: 0.152576, HeadSupport: 79862, HeadSize: 79862, Time: 293 ms
