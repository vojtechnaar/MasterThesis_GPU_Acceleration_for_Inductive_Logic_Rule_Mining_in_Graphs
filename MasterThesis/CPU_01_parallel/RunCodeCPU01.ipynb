# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -lah /content/drive/MyDrive/MasterThesis/MasterThesis/CPU_01_parallel
# Out:
# total 894K
# -rw------- 1 root root  900 Mar 24 02:29 FinalRule.cpp
# -rw------- 1 root root  941 Mar 24 02:29 FinalRule.hpp
# -rw------- 1 root root  38K Mar 24 23:08 gmon.out
# -rw------- 1 root root 7.6K Mar 28 14:04 main.cpp
# -rw------- 1 root root 6.8K Mar 24 02:29 RdfIndexes.cpp
# -rw------- 1 root root 1.9K Mar 24 02:29 RdfIndexes.hpp
# -rw------- 1 root root 103K Mar 24 02:42 rdf_rules_test
# -rw------- 1 root root 103K Mar 24 23:05 rdf_rules_test_profiled
# -rw------- 1 root root 6.1K Mar 22 03:06 RuleParser.cpp
# -rw------- 1 root root  780 Mar 22 03:06 RuleParser.hpp
# -rw------- 1 root root 611K Mar 28 13:49 RunCodeCPU01.ipynb
# -rw------- 1 root root  12K Mar 28 14:04 SupportCounting.cpp
# -rw------- 1 root root 2.0K Mar 24 02:26 SupportCounting.hpp

# %%
# %cd /content/drive/MyDrive/MasterThesis/MasterThesis/CPU_01_parallel
# Out:
# /content/drive/MyDrive/MasterThesis/MasterThesis/CPU_01_parallel

# %%
# !sudo apt-get update
# !sudo apt-get install -y libraptor2-dev
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,932 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,620 kB]
# ...

# %%
# !g++ -std=c++17 -fopenmp main.cpp RdfIndexes.cpp FinalRule.cpp SupportCounting.cpp RuleParser.cpp $(pkg-config --cflags --libs raptor2) -O2 -o rdf_rules_test

# %%
# !ls -lah
# Out:
# total 295K
# -rw------- 1 root root  900 Mar 24 02:29 FinalRule.cpp
# -rw------- 1 root root  941 Mar 24 02:29 FinalRule.hpp
# -rw------- 1 root root  38K Mar 24 23:08 gmon.out
# -rw------- 1 root root 7.6K Mar 28 14:04 main.cpp
# -rw------- 1 root root 6.8K Mar 24 02:29 RdfIndexes.cpp
# -rw------- 1 root root 1.9K Mar 24 02:29 RdfIndexes.hpp
# -rwx------ 1 root root 109K Mar 28 14:06 rdf_rules_test
# -rw------- 1 root root 103K Mar 24 23:05 rdf_rules_test_profiled
# -rw------- 1 root root 6.1K Mar 22 03:06 RuleParser.cpp
# -rw------- 1 root root  780 Mar 22 03:06 RuleParser.hpp
# -rw------- 1 root root 5.8K Mar 28 14:05 RunCodeCPU01.ipynb
# -rw------- 1 root root  12K Mar 28 14:04 SupportCounting.cpp
# -rw------- 1 root root 2.0K Mar 24 02:26 SupportCounting.hpp

# %%
# !./rdf_rules_test ../test_data/original_train.ttl ../test_data/rules_150minutes.txt
# Out:
# === Index built ===
# Triples (deduped): 6794977
# Unique RDF terms: 3164825
# Predicates: 26
#
# === Rules loaded ===
# Rule count: 736
# OpenMP threads: 2
#
# Rule 1: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0 ms
#
# Rule 2: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 47 ms
#
# Rule 3: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 48 ms
#
# Rule 4: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?1 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 9582, HeadCoverage: 0.0776254, HeadSupport: 123439, HeadSize: 123439, Time: 63 ms
#
# ...

# %% [markdown]
# PROFILING

# %%
# !g++ -std=c++17 -fopenmp -pg main.cpp RdfIndexes.cpp FinalRule.cpp SupportCounting.cpp RuleParser.cpp $(pkg-config --cflags --libs raptor2) -O2 -o rdf_rules_test_profiled

# %%
# !./rdf_rules_test_profiled ../test_data/original_train.ttl ../test_data/rules_150minutes.txt
# Out:
# === Index built ===
# Triples (deduped): 6794977
# Unique RDF terms: 3164825
# Predicates: 26
#
# === Rules loaded ===
# Rule count: 736
# OpenMP threads: 2
#
# Rule 1: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 1 ms
#
# Rule 2: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 84 ms
#
# Rule 3: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 84 ms
#
# Rule 4: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?1 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 9582, HeadCoverage: 0.0776254, HeadSupport: 123439, HeadSize: 123439, Time: 128 ms
#
# ...

# %%
# !gprof rdf_rules_test_profiled gmon.out
# Out:
# Flat profile:
#
# Each sample counts as 0.01 seconds.
#   %   cumulative   self              self     total
#  time   seconds   seconds    calls   s/call   s/call  name
#  30.53     33.28    33.28 435289819     0.00     0.00  std::_Rb_tree<int, std::pair<int const, std::vector<long long, std::allocator<long long> > >, std::_Select1st<std::pair<int const, std::vector<long long, std::allocator<long long> > > >, std::less<int>, std::allocator<std::pair<int const, std::vector<long long, std::allocator<long long> > > > >::_M_get_insert_hint_unique_pos(std::_Rb_tree_const_iterator<std::pair<int const, std::vector<long long, std::allocator<long long> > > >, int const&)
#  17.27     52.10    18.82 453709599     0.00     0.00  RdfIndexes::getPred(int) const
#  14.74     68.16    16.06 26975272     0.00     0.00  bool SupportCounting::dfsExists<3>(Atom const*, unsigned char, Env&, int) const
#   7.18     75.99     7.83 237787862     0.00     0.00  PredIndex::hasTriple(int, int) const
# ...
