# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -lah /content/drive/MyDrive/MasterThesis/MasterThesis/GPU_03
# Out:
# total 53K
# -rw------- 1 root root  18K Mar 29 00:04 bench_gpu.cu
# -rw------- 1 root root  900 Mar 24 02:29 FinalRule.cpp
# -rw------- 1 root root  941 Mar 24 02:29 FinalRule.hpp
# -rw------- 1 root root  934 Mar 29 00:01 gpu_common.cuh
# -rw------- 1 root root 5.0K Mar 29 00:01 gpu_index.cuh
# -rw------- 1 root root 8.0K Mar 29 00:02 gpu_kernels.cuh
# -rw------- 1 root root 6.8K Mar 24 02:29 RdfIndexes.cpp
# -rw------- 1 root root 1.9K Mar 24 02:29 RdfIndexes.hpp
# -rw------- 1 root root 6.1K Mar 22 03:06 RuleParser.cpp
# -rw------- 1 root root  780 Mar 22 03:06 RuleParser.hpp
# -rw------- 1 root root 1.6K Mar 29 00:05 RunCodeGPU03.ipynb

# %%
# %cd /content/drive/MyDrive/MasterThesis/MasterThesis/GPU_03
# Out:
# /content/drive/MyDrive/MasterThesis/MasterThesis/GPU_03

# %%
# !nvidia-smi
# Out:
# Sun Mar 29 00:06:01 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !sudo apt-get update
# !sudo apt-get install -y libraptor2-dev
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,473 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,309 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,803 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,842 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,620 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,947 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,173 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,011 kB]
# Get:21 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,932 kB]
# Fetched 40.5 MB in 4s (10.8 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libcurl3-gnutls libcurl4-gnutls-dev libraptor2-0 libxslt1-dev libyajl-dev
#   libyajl2 raptor2-utils
# Suggested packages:
#   libcurl4-doc libgnutls28-dev libidn11-dev libldap2-dev librtmp-dev
#   libraptor2-doc
# The following packages will be REMOVED:
#   libcurl4-openssl-dev
# The following NEW packages will be installed:
#   libcurl4-gnutls-dev libraptor2-0 libraptor2-dev libxslt1-dev libyajl-dev
#   libyajl2 raptor2-utils
# The following packages will be upgraded:
#   libcurl3-gnutls
# 1 upgraded, 7 newly installed, 1 to remove and 60 not upgraded.
# Need to get 1,341 kB of archives.
# After this operation, 3,669 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl3-gnutls amd64 7.81.0-1ubuntu1.23 [284 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4-gnutls-dev amd64 7.81.0-1ubuntu1.23 [380 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl2 amd64 2.1.0-3ubuntu0.22.04.1 [21.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4.1 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxslt1-dev amd64 1.1.34-4ubuntu0.22.04.5 [219 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl-dev amd64 2.1.0-3ubuntu0.22.04.1 [28.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraptor2-dev amd64 2.0.15-0ubuntu4.1 [221 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 raptor2-utils amd64 2.0.15-0ubuntu4.1 [14.5 kB]
# Fetched 1,341 kB in 1s (1,551 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 8.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../libcurl3-gnutls_7.81.0-1ubuntu1.23_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.81.0-1ubuntu1.23) over (7.81.0-1ubuntu1.21) ...
# dpkg: libcurl4-openssl-dev:amd64: dependency problems, but removing anyway as you requested:
#  libhdf5-dev depends on libcurl4-openssl-dev | libcurl-dev; however:
#   Package libcurl4-openssl-dev:amd64 is to be removed.
#   Package libcurl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-dev is to be removed.
#  libhdf5-dev depends on libcurl4-openssl-dev | libcurl-dev; however:
#   Package libcurl4-openssl-dev:amd64 is to be removed.
#   Package libcurl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-dev is to be removed.
#  libproj-dev:amd64 depends on libcurl4-gnutls-dev | libcurl-ssl-dev; however:
#   Package libcurl4-gnutls-dev is not installed.
#   Package libcurl-ssl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-ssl-dev is to be removed.
#  libnetcdf-dev depends on libcurl4-gnutls-dev | libcurl-ssl-dev; however:
#   Package libcurl4-gnutls-dev is not installed.
#   Package libcurl-ssl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-ssl-dev is to be removed.
#  libgdal-dev depends on libcurl4-gnutls-dev | libcurl-ssl-dev; however:
#   Package libcurl4-gnutls-dev is not installed.
#   Package libcurl-ssl-dev is not installed.
#   Package libcurl4-openssl-dev:amd64 which provides libcurl-ssl-dev is to be removed.
#
# (Reading database ... 122354 files and directories currently installed.)
# Removing libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.23) ...
# Selecting previously unselected package libcurl4-gnutls-dev:amd64.
# (Reading database ... 122333 files and directories currently installed.)
# Preparing to unpack .../0-libcurl4-gnutls-dev_7.81.0-1ubuntu1.23_amd64.deb ...
# Unpacking libcurl4-gnutls-dev:amd64 (7.81.0-1ubuntu1.23) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../1-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../2-libraptor2-0_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Selecting previously unselected package libxslt1-dev:amd64.
# Preparing to unpack .../3-libxslt1-dev_1.1.34-4ubuntu0.22.04.5_amd64.deb ...
# Unpacking libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.5) ...
# Selecting previously unselected package libyajl-dev:amd64.
# Preparing to unpack .../4-libyajl-dev_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl-dev:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-dev.
# Preparing to unpack .../5-libraptor2-dev_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking libraptor2-dev (2.0.15-0ubuntu4.1) ...
# Selecting previously unselected package raptor2-utils.
# Preparing to unpack .../6-raptor2-utils_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking raptor2-utils (2.0.15-0ubuntu4.1) ...
# Setting up libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.5) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libcurl3-gnutls:amd64 (7.81.0-1ubuntu1.23) ...
# Setting up libcurl4-gnutls-dev:amd64 (7.81.0-1ubuntu1.23) ...
# Setting up libyajl-dev:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Setting up raptor2-utils (2.0.15-0ubuntu4.1) ...
# Setting up libraptor2-dev (2.0.15-0ubuntu4.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link

# %%
# !nvcc -O3 -std=c++17 bench_gpu.cu FinalRule.cpp RdfIndexes.cpp RuleParser.cpp $(pkg-config --cflags --libs raptor2) -o bench_gpu
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !ls -lah bench_gpu
# Out:
# -rwx------ 1 root root 4.5M Mar 29 00:07 bench_gpu

# %%
# !./bench_gpu ../test_data/original_train.ttl ../test_data/rules_150minutes.txt
# Out:
# === Index built ===
# Triples (deduped): 6794977
# Unique RDF terms: 3164825
# Predicates: 26
# Entity count: 3164825
# CSR index built: 26 predicates  (1656 ms)
#
# === Rules loaded ===
# Rule count: 736
#
#
# Rule 1: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0.067232 ms
#
# Rule 2: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 0.024064 ms
#
# Rule 3: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 0.021248 ms
#
# Rule 4: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?1 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 11516, HeadCoverage: 0.093293, HeadSupport: 123439, HeadSize: 123439, Time: 0.037312 ms
#
# Rule 5: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) => ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 4504, HeadCoverage: 0.0381436, HeadSupport: 118080, HeadSize: 118080, Time: 0.026912 ms
#
# Rule 6: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 22917, HeadCoverage: 0.19408, HeadSupport: 118080, HeadSize: 118080, Time: 0.026592 ms
#
# Rule 7: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?1 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 21732, HeadCoverage: 0.185718, HeadSupport: 117016, HeadSize: 117016, Time: 0.035072 ms
#
# Rule 8: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 4504, HeadCoverage: 0.0325084, HeadSupport: 138549, HeadSize: 138549, Time: 0.034336 ms
#
# Rule 9: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 22917, HeadCoverage: 0.193508, HeadSupport: 118429, HeadSize: 118429, Time: 0.028448 ms
#
# Rule 10: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) | Support: 9, HeadCoverage: 0.0422535, HeadSupport: 213, HeadSize: 213, Time: 0.04048 ms
#
# Rule 11: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?2 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) | Support: 9, HeadCoverage: 0.0422535, HeadSupport: 213, HeadSize: 213, Time: 0.010656 ms
#
# Rule 12: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) | Support: 213, HeadCoverage: 1, HeadSupport: 213, HeadSize: 213, Time: 0.010208 ms
#
# Rule 13: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?1 ) | Support: 106, HeadCoverage: 0.946429, HeadSupport: 112, HeadSize: 112, Time: 0.031168 ms
#
# Rule 14: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) | Support: 98, HeadCoverage: 0.875, HeadSupport: 112, HeadSize: 112, Time: 0.011232 ms
#
# Rule 15: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 15, HeadCoverage: 0.0141243, HeadSupport: 1062, HeadSize: 1062, Time: 0.540896 ms
#
# Rule 16: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 0.032448 ms
#
# Rule 17: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 0.032768 ms
#
# Rule 18: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0.012288 ms
#
# Rule 19: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 0.01568 ms
#
# Rule 20: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 68, HeadCoverage: 0.0640301, HeadSupport: 1062, HeadSize: 1062, Time: 0.02848 ms
#
# Rule 21: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 0.053088 ms
#
# Rule 22: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 209, HeadCoverage: 0.196798, HeadSupport: 1062, HeadSize: 1062, Time: 0.041376 ms
#
# Rule 23: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 62, HeadCoverage: 0.0583804, HeadSupport: 1062, HeadSize: 1062, Time: 0.026624 ms
#
# Rule 24: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 263, HeadCoverage: 0.247646, HeadSupport: 1062, HeadSize: 1062, Time: 0.483616 ms
#
# Rule 25: ( ?0 https://w3id.org/biolink/vocab/assesses ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/capable_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) | Support: 94, HeadCoverage: 0.839286, HeadSupport: 112, HeadSize: 112, Time: 0.078944 ms
#
# Rule 26: ( ?0 https://w3id.org/biolink/vocab/enabled_by ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?1 ) | Support: 423, HeadCoverage: 0.0553955, HeadSupport: 7636, HeadSize: 7636, Time: 0.033344 ms
#
# Rule 27: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/enables ?1 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?0 ) | Support: 3747, HeadCoverage: 0.490702, HeadSupport: 7636, HeadSize: 7636, Time: 0.014944 ms
#
# Rule 28: ( ?0 https://w3id.org/biolink/vocab/enabled_by ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?1 ) | Support: 209, HeadCoverage: 0.0273704, HeadSupport: 7636, HeadSize: 7636, Time: 0.03248 ms
#
# Rule 29: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 15054, HeadCoverage: 0.298946, HeadSupport: 50357, HeadSize: 50357, Time: 0.021184 ms
#
# Rule 30: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?0 ) | Support: 624, HeadCoverage: 0.0240462, HeadSupport: 25950, HeadSize: 25950, Time: 0.022048 ms
#
# Rule 31: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/occurs_in ?2 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 13229, HeadCoverage: 0.262704, HeadSupport: 50357, HeadSize: 50357, Time: 0.271168 ms
#
# Rule 32: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?1 ) | Support: 6833, HeadCoverage: 0.263314, HeadSupport: 25950, HeadSize: 25950, Time: 0.018912 ms
#
# Rule 33: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?1 ) | Support: 1279, HeadCoverage: 0.0492871, HeadSupport: 25950, HeadSize: 25950, Time: 5.46208 ms
#
# Rule 34: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/produces ?1 ) | Support: 217, HeadCoverage: 0.0621242, HeadSupport: 3493, HeadSize: 3493, Time: 0.014336 ms
#
# Rule 35: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/produces ?1 ) | Support: 162, HeadCoverage: 0.0463785, HeadSupport: 3493, HeadSize: 3493, Time: 0.341664 ms
#
# Rule 36: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) | Support: 3102, HeadCoverage: 0.0933353, HeadSupport: 33235, HeadSize: 33235, Time: 0.148128 ms
#
# Rule 37: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) | Support: 995, HeadCoverage: 0.0299383, HeadSupport: 33235, HeadSize: 33235, Time: 0.133536 ms
#
# Rule 38: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?1 ) | Support: 1528, HeadCoverage: 0.0459756, HeadSupport: 33235, HeadSize: 33235, Time: 0.021408 ms
#
# Rule 39: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 3609, HeadCoverage: 0.0451905, HeadSupport: 79862, HeadSize: 79862, Time: 22.3155 ms
#
# Rule 40: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?1 ) | Support: 1347, HeadCoverage: 0.0405296, HeadSupport: 33235, HeadSize: 33235, Time: 2.67571 ms
#
# Rule 41: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?0 ) | Support: 1322, HeadCoverage: 0.0165536, HeadSupport: 79862, HeadSize: 79862, Time: 0.06368 ms
#
# Rule 42: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 1341, HeadCoverage: 0.0167915, HeadSupport: 79862, HeadSize: 79862, Time: 0.054848 ms
#
# Rule 43: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 3609, HeadCoverage: 0.0451905, HeadSupport: 79862, HeadSize: 79862, Time: 22.5994 ms
#
# Rule 44: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 12185, HeadCoverage: 0.152576, HeadSupport: 79862, HeadSize: 79862, Time: 0.033088 ms
#
# Rule 45: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 79862, HeadCoverage: 1, HeadSupport: 79862, HeadSize: 79862, Time: 0.031648 ms
#
# Rule 46: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/enabled_by ?0 ) => ( ?2 https://w3id.org/biolink/vocab/enables ?1 ) | Support: 3738, HeadCoverage: 0.841323, HeadSupport: 4443, HeadSize: 4443, Time: 0.027232 ms
#
# Rule 47: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?0 ) | Support: 1322, HeadCoverage: 0.0165536, HeadSupport: 79862, HeadSize: 79862, Time: 0.05984 ms
#
# Rule 48: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_output ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 1341, HeadCoverage: 0.0167915, HeadSupport: 79862, HeadSize: 79862, Time: 0.052512 ms
#
# Rule 49: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/enables ?0 ) | Support: 4439, HeadCoverage: 0.9991, HeadSupport: 4443, HeadSize: 4443, Time: 0.015424 ms
#
# Rule 50: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 12185, HeadCoverage: 0.152576, HeadSupport: 79862, HeadSize: 79862, Time: 0.030752 ms
#
# Rule 51: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 79862, HeadCoverage: 1, HeadSupport: 79862, HeadSize: 79862, Time: 0.030368 ms
#
# Rule 52: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 123439, HeadCoverage: 1, HeadSupport: 123439, HeadSize: 123439, Time: 0.038528 ms
#
# Rule 53: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_part ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 11506, HeadCoverage: 0.093212, HeadSupport: 123439, HeadSize: 123439, Time: 0.713312 ms
#
# Rule 54: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_part ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) | Support: 76407, HeadCoverage: 0.618986, HeadSupport: 123439, HeadSize: 123439, Time: 27.3969 ms
#
# Rule 55: ( ?0 https://w3id.org/biolink/vocab/is_assessed_by ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/assesses ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?0 ) | Support: 13764, HeadCoverage: 0.116565, HeadSupport: 118080, HeadSize: 118080, Time: 0.164896 ms
#
# Rule 56: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 1939, HeadCoverage: 0.0164211, HeadSupport: 118080, HeadSize: 118080, Time: 0.030528 ms
#
# Rule 57: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 8623, HeadCoverage: 0.0730268, HeadSupport: 118080, HeadSize: 118080, Time: 0.031008 ms
#
# Rule 58: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 1206, HeadCoverage: 0.0102134, HeadSupport: 118080, HeadSize: 118080, Time: 9.17405 ms
#
# Rule 59: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 3552, HeadCoverage: 0.0300813, HeadSupport: 118080, HeadSize: 118080, Time: 36.6092 ms
#
# Rule 60: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 5320, HeadCoverage: 0.0450542, HeadSupport: 118080, HeadSize: 118080, Time: 7.49824 ms
#
# Rule 61: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 1978, HeadCoverage: 0.0167514, HeadSupport: 118080, HeadSize: 118080, Time: 0.516032 ms
#
# Rule 62: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?0 ) | Support: 2994, HeadCoverage: 0.0253557, HeadSupport: 118080, HeadSize: 118080, Time: 0.343968 ms
#
# Rule 63: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 3613, HeadCoverage: 0.0308761, HeadSupport: 117016, HeadSize: 117016, Time: 9.42493 ms
#
# Rule 64: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 8635, HeadCoverage: 0.0737933, HeadSupport: 117016, HeadSize: 117016, Time: 0.097152 ms
#
# Rule 65: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 6844, HeadCoverage: 0.0584877, HeadSupport: 117016, HeadSize: 117016, Time: 0.095904 ms
#
# Rule 66: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 7450, HeadCoverage: 0.0636665, HeadSupport: 117016, HeadSize: 117016, Time: 9.02058 ms
#
# Rule 67: ( ?0 https://w3id.org/biolink/vocab/enables ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/enabled_by ?2 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 3744, HeadCoverage: 0.0319956, HeadSupport: 117016, HeadSize: 117016, Time: 0.026432 ms
#
# Rule 68: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 24973, HeadCoverage: 0.20231, HeadSupport: 123439, HeadSize: 123439, Time: 0.343744 ms
#
# Rule 69: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) | Support: 106048, HeadCoverage: 0.859113, HeadSupport: 123439, HeadSize: 123439, Time: 0.814336 ms
#
# Rule 70: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 110638, HeadCoverage: 0.945495, HeadSupport: 117016, HeadSize: 117016, Time: 0.036896 ms
#
# Rule 71: ( ?0 https://w3id.org/biolink/vocab/synonym ?1 ) ^ ( ?2 http://www.w3.org/2000/01/rdf-schema#label ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 2459, HeadCoverage: 0.0210142, HeadSupport: 117016, HeadSize: 117016, Time: 0.048864 ms
#
# Rule 72: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 6976, HeadCoverage: 0.0596158, HeadSupport: 117016, HeadSize: 117016, Time: 0.072096 ms
#
# Rule 73: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 10897, HeadCoverage: 0.093124, HeadSupport: 117016, HeadSize: 117016, Time: 0.067648 ms
#
# Rule 74: ( ?0 http://www.w3.org/2000/01/rdf-schema#label ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/synonym ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 2442, HeadCoverage: 0.0208689, HeadSupport: 117016, HeadSize: 117016, Time: 0.043008 ms
#
# Rule 75: ( ?0 https://w3id.org/biolink/vocab/synonym ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/synonym ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 2331, HeadCoverage: 0.0199204, HeadSupport: 117016, HeadSize: 117016, Time: 0.5448 ms
#
# Rule 76: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 12031, HeadCoverage: 0.0868357, HeadSupport: 138549, HeadSize: 138549, Time: 0.038048 ms
#
# Rule 77: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 3626, HeadCoverage: 0.0261712, HeadSupport: 138549, HeadSize: 138549, Time: 77.7073 ms
#
# Rule 78: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 77321, HeadCoverage: 0.5, HeadSupport: 154642, HeadSize: 154642, Time: 26.8146 ms
#
# Rule 79: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 77321, HeadCoverage: 0.5, HeadSupport: 154642, HeadSize: 154642, Time: 14.9381 ms
#
# Rule 80: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 80893, HeadCoverage: 0.523099, HeadSupport: 154642, HeadSize: 154642, Time: 25.2867 ms
#
# Rule 81: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?1 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 4110, HeadCoverage: 0.0816173, HeadSupport: 50357, HeadSize: 50357, Time: 0.02048 ms
#
# Rule 82: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?1 ) | Support: 3364, HeadCoverage: 0.066803, HeadSupport: 50357, HeadSize: 50357, Time: 0.892736 ms
#
# Rule 83: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 89519, HeadCoverage: 0.578879, HeadSupport: 154642, HeadSize: 154642, Time: 0.026624 ms
#
# Rule 84: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?0 ) | Support: 2674, HeadCoverage: 0.0172916, HeadSupport: 154642, HeadSize: 154642, Time: 0.058592 ms
#
# Rule 85: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 2704, HeadCoverage: 0.0174855, HeadSupport: 154642, HeadSize: 154642, Time: 0.051936 ms
#
# Rule 86: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/assesses ?2 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 11972, HeadCoverage: 0.10109, HeadSupport: 118429, HeadSize: 118429, Time: 0.092224 ms
#
# Rule 87: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 2582, HeadCoverage: 0.0218021, HeadSupport: 118429, HeadSize: 118429, Time: 0.048768 ms
#
# Rule 88: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 5348, HeadCoverage: 0.0451579, HeadSupport: 118429, HeadSize: 118429, Time: 0.017152 ms
#
# Rule 89: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 3554, HeadCoverage: 0.0300095, HeadSupport: 118429, HeadSize: 118429, Time: 0.015776 ms
#
# Rule 90: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 2818, HeadCoverage: 0.0237948, HeadSupport: 118429, HeadSize: 118429, Time: 10.5533 ms
#
# Rule 91: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 1997, HeadCoverage: 0.0168624, HeadSupport: 118429, HeadSize: 118429, Time: 0.033664 ms
#
# Rule 92: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 2973, HeadCoverage: 0.0251036, HeadSupport: 118429, HeadSize: 118429, Time: 0.079872 ms
#
# Rule 93: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 1794, HeadCoverage: 0.0151483, HeadSupport: 118429, HeadSize: 118429, Time: 0.073728 ms
#
# Rule 94: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 1904, HeadCoverage: 0.0160771, HeadSupport: 118429, HeadSize: 118429, Time: 0.032768 ms
#
# Rule 95: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 1872, HeadCoverage: 0.0158069, HeadSupport: 118429, HeadSize: 118429, Time: 0.294336 ms
#
# Rule 96: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 1688, HeadCoverage: 0.0142533, HeadSupport: 118429, HeadSize: 118429, Time: 0.30336 ms
#
# Rule 97: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 34028, HeadCoverage: 0.0258071, HeadSupport: 1318552, HeadSize: 1318552, Time: 1.1991 ms
#
# Rule 98: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 67852, HeadCoverage: 0.0514595, HeadSupport: 1318552, HeadSize: 1318552, Time: 0.116736 ms
#
# Rule 99: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 118994, HeadCoverage: 0.090246, HeadSupport: 1318552, HeadSize: 1318552, Time: 1.34554 ms
#
# Rule 100: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 1259536, HeadCoverage: 0.955242, HeadSupport: 1318552, HeadSize: 1318552, Time: 0.19072 ms
#
# Rule 101: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) | Support: 13848, HeadCoverage: 0.0100067, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.132992 ms
#
# Rule 102: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 32820, HeadCoverage: 0.023716, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.094208 ms
#
# Rule 103: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 32820, HeadCoverage: 0.023716, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.094816 ms
#
# Rule 104: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 24754, HeadCoverage: 0.0178875, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.087008 ms
#
# Rule 105: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 1375885, HeadCoverage: 0.994228, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.165792 ms
#
# Rule 106: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/inverseOf ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 5, HeadCoverage: 0.0234742, HeadSupport: 213, HeadSize: 213, Time: 0.057184 ms
#
# Rule 107: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 20, HeadCoverage: 0.0938967, HeadSupport: 213, HeadSize: 213, Time: 0.008 ms
#
# Rule 108: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 46, HeadCoverage: 0.215962, HeadSupport: 213, HeadSize: 213, Time: 0.008192 ms
#
# Rule 109: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 20, HeadCoverage: 0.0938967, HeadSupport: 213, HeadSize: 213, Time: 0.022528 ms
#
# Rule 110: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 95, HeadCoverage: 0.446009, HeadSupport: 213, HeadSize: 213, Time: 0.008192 ms
#
# Rule 111: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 53, HeadCoverage: 0.248826, HeadSupport: 213, HeadSize: 213, Time: 0.01008 ms
#
# Rule 112: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 39, HeadCoverage: 0.183099, HeadSupport: 213, HeadSize: 213, Time: 0.026624 ms
#
# Rule 113: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 102, HeadCoverage: 0.478873, HeadSupport: 213, HeadSize: 213, Time: 0.008192 ms
#
# Rule 114: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 5, HeadCoverage: 0.0234742, HeadSupport: 213, HeadSize: 213, Time: 0.006336 ms
#
# Rule 115: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/inverseOf ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 20, HeadCoverage: 0.0938967, HeadSupport: 213, HeadSize: 213, Time: 0.007616 ms
#
# Rule 116: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 49, HeadCoverage: 0.230047, HeadSupport: 213, HeadSize: 213, Time: 0.007136 ms
#
# Rule 117: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?0 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 43, HeadCoverage: 0.201878, HeadSupport: 213, HeadSize: 213, Time: 0.006176 ms
#
# Rule 118: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 40, HeadCoverage: 0.187793, HeadSupport: 213, HeadSize: 213, Time: 0.008032 ms
#
# Rule 119: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 170, HeadCoverage: 0.798122, HeadSupport: 213, HeadSize: 213, Time: 0.007904 ms
#
# Rule 120: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 154, HeadCoverage: 0.723005, HeadSupport: 213, HeadSize: 213, Time: 0.007168 ms
#
# Rule 121: ( ?0 https://w3id.org/biolink/vocab/part_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/part_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/part_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/part_of ?2 ) | Support: 12, HeadCoverage: 0.0235756, HeadSupport: 509, HeadSize: 509, Time: 0.018208 ms
#
# Rule 122: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/part_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/part_of ?2 ) | Support: 12, HeadCoverage: 0.0235756, HeadSupport: 509, HeadSize: 509, Time: 0.008608 ms
#
# Rule 123: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/part_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/part_of ?2 ) | Support: 24, HeadCoverage: 0.0471513, HeadSupport: 509, HeadSize: 509, Time: 0.009344 ms
#
# Rule 124: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/part_of ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/part_of ?2 ) | Support: 323, HeadCoverage: 0.634578, HeadSupport: 509, HeadSize: 509, Time: 0.016384 ms
#
# Rule 125: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/occurs_in ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/enabled_by ?3 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 11, HeadCoverage: 0.0982143, HeadSupport: 112, HeadSize: 112, Time: 0.01024 ms
#
# Rule 126: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 21, HeadCoverage: 0.1875, HeadSupport: 112, HeadSize: 112, Time: 0.813056 ms
#
# Rule 127: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 3, HeadCoverage: 0.0267857, HeadSupport: 112, HeadSize: 112, Time: 0.859072 ms
#
# Rule 128: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/part_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/part_of ?2 ) | Support: 269, HeadCoverage: 0.528487, HeadSupport: 509, HeadSize: 509, Time: 0.047552 ms
#
# Rule 129: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 95, HeadCoverage: 0.848214, HeadSupport: 112, HeadSize: 112, Time: 0.012288 ms
#
# Rule 130: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/occurs_in ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?1 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 78, HeadCoverage: 0.696429, HeadSupport: 112, HeadSize: 112, Time: 0.021888 ms
#
# Rule 131: ( ?0 https://w3id.org/biolink/vocab/assesses ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 76, HeadCoverage: 0.678571, HeadSupport: 112, HeadSize: 112, Time: 1.98042 ms
#
# Rule 132: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 226, HeadCoverage: 0.212806, HeadSupport: 1062, HeadSize: 1062, Time: 0.009984 ms
#
# Rule 133: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 11, HeadCoverage: 0.0103578, HeadSupport: 1062, HeadSize: 1062, Time: 0.081024 ms
#
# Rule 134: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 27, HeadCoverage: 0.0254237, HeadSupport: 1062, HeadSize: 1062, Time: 0.09872 ms
#
# Rule 135: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 37, HeadCoverage: 0.0348399, HeadSupport: 1062, HeadSize: 1062, Time: 0.067584 ms
#
# Rule 136: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?1 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 41, HeadCoverage: 0.0386064, HeadSupport: 1062, HeadSize: 1062, Time: 1.04448 ms
#
# Rule 137: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 28, HeadCoverage: 0.0263653, HeadSupport: 1062, HeadSize: 1062, Time: 1.7879 ms
#
# Rule 138: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 0.025184 ms
#
# Rule 139: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 0.022528 ms
#
# Rule 140: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 236, HeadCoverage: 0.222222, HeadSupport: 1062, HeadSize: 1062, Time: 0.024992 ms
#
# Rule 141: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 914, HeadCoverage: 0.86064, HeadSupport: 1062, HeadSize: 1062, Time: 0.01024 ms
#
# Rule 142: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 11, HeadCoverage: 0.0103578, HeadSupport: 1062, HeadSize: 1062, Time: 0.026624 ms
#
# Rule 143: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 37, HeadCoverage: 0.0348399, HeadSupport: 1062, HeadSize: 1062, Time: 0.027488 ms
#
# Rule 144: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 41, HeadCoverage: 0.0386064, HeadSupport: 1062, HeadSize: 1062, Time: 0.051072 ms
#
# Rule 145: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.430624 ms
#
# Rule 146: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.184128 ms
#
# Rule 147: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 385, HeadCoverage: 0.362524, HeadSupport: 1062, HeadSize: 1062, Time: 0.011584 ms
#
# Rule 148: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0.008192 ms
#
# Rule 149: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 960, HeadCoverage: 0.903955, HeadSupport: 1062, HeadSize: 1062, Time: 0.01024 ms
#
# Rule 150: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 29, HeadCoverage: 0.027307, HeadSupport: 1062, HeadSize: 1062, Time: 0.016544 ms
#
# Rule 151: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 135, HeadCoverage: 0.127119, HeadSupport: 1062, HeadSize: 1062, Time: 0.022528 ms
#
# Rule 152: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 68, HeadCoverage: 0.0640301, HeadSupport: 1062, HeadSize: 1062, Time: 0.014816 ms
#
# Rule 153: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 236, HeadCoverage: 0.222222, HeadSupport: 1062, HeadSize: 1062, Time: 0.0264 ms
#
# Rule 154: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 18, HeadCoverage: 0.0169492, HeadSupport: 1062, HeadSize: 1062, Time: 0.024192 ms
#
# Rule 155: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 1016, HeadCoverage: 0.956685, HeadSupport: 1062, HeadSize: 1062, Time: 0.010144 ms
#
# Rule 156: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.434176 ms
#
# Rule 157: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 691, HeadCoverage: 0.650659, HeadSupport: 1062, HeadSize: 1062, Time: 0.316544 ms
#
# Rule 158: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 27, HeadCoverage: 0.0254237, HeadSupport: 1062, HeadSize: 1062, Time: 0.035744 ms
#
# Rule 159: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 1053, HeadCoverage: 0.991525, HeadSupport: 1062, HeadSize: 1062, Time: 0.014336 ms
#
# Rule 160: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0.008192 ms
#
# Rule 161: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 0.017632 ms
#
# Rule 162: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 414, HeadCoverage: 0.389831, HeadSupport: 1062, HeadSize: 1062, Time: 0.273728 ms
#
# Rule 163: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.466944 ms
#
# Rule 164: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 829, HeadCoverage: 0.780603, HeadSupport: 1062, HeadSize: 1062, Time: 10.3122 ms
#
# Rule 165: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/subclass_of ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 21, HeadCoverage: 0.019774, HeadSupport: 1062, HeadSize: 1062, Time: 0.061344 ms
#
# ...
#
# Rule 690: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 24687, HeadCoverage: 0.199994, HeadSupport: 123439, HeadSize: 123439, Time: 1.17421 ms
#
# Rule 691: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 24687, HeadCoverage: 0.199994, HeadSupport: 123439, HeadSize: 123439, Time: 0.90112 ms
#
# Rule 692: ( ?0 http://www.w3.org/2000/01/rdf-schema#label ?1 ) ^ ( ?2 http://www.w3.org/2000/01/rdf-schema#label ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 1963, HeadCoverage: 0.0159026, HeadSupport: 123439, HeadSize: 123439, Time: 0.512288 ms
#
# Rule 693: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 1563, HeadCoverage: 0.0126621, HeadSupport: 123439, HeadSize: 123439, Time: 247.95 ms
#
# Rule 694: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 5670, HeadCoverage: 0.0459336, HeadSupport: 123439, HeadSize: 123439, Time: 0.892576 ms
#
# Rule 695: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 5172, HeadCoverage: 0.0418992, HeadSupport: 123439, HeadSize: 123439, Time: 4.57728 ms
#
# Rule 696: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 1581, HeadCoverage: 0.0128079, HeadSupport: 123439, HeadSize: 123439, Time: 25.1425 ms
#
# Rule 697: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 31061, HeadCoverage: 0.26305, HeadSupport: 118080, HeadSize: 118080, Time: 121.979 ms
#
# Rule 698: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 31322, HeadCoverage: 0.265261, HeadSupport: 118080, HeadSize: 118080, Time: 3.82771 ms
#
# Rule 699: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 29465, HeadCoverage: 0.249534, HeadSupport: 118080, HeadSize: 118080, Time: 229.597 ms
#
# Rule 700: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 10915, HeadCoverage: 0.0924373, HeadSupport: 118080, HeadSize: 118080, Time: 0.290816 ms
#
# Rule 701: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_part ?0 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) | Support: 19819, HeadCoverage: 0.160557, HeadSupport: 123439, HeadSize: 123439, Time: 0.258656 ms
#
# Rule 702: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 46282, HeadCoverage: 0.374938, HeadSupport: 123439, HeadSize: 123439, Time: 1.39229 ms
#
# Rule 703: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 20526, HeadCoverage: 0.166285, HeadSupport: 123439, HeadSize: 123439, Time: 0.051552 ms
#
# Rule 704: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 75456, HeadCoverage: 0.639024, HeadSupport: 118080, HeadSize: 118080, Time: 10.2097 ms
#
# Rule 705: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 114362, HeadCoverage: 0.968513, HeadSupport: 118080, HeadSize: 118080, Time: 6.92298 ms
#
# Rule 706: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 87606, HeadCoverage: 0.741921, HeadSupport: 118080, HeadSize: 118080, Time: 13.8924 ms
#
# Rule 707: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 84036, HeadCoverage: 0.711687, HeadSupport: 118080, HeadSize: 118080, Time: 9.10749 ms
#
# Rule 708: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 28793, HeadCoverage: 0.243843, HeadSupport: 118080, HeadSize: 118080, Time: 1.33117 ms
#
# Rule 709: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 22709, HeadCoverage: 0.183969, HeadSupport: 123439, HeadSize: 123439, Time: 1.04813 ms
#
# Rule 710: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 3710, HeadCoverage: 0.0300553, HeadSupport: 123439, HeadSize: 123439, Time: 1.0049 ms
#
# Rule 711: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 5979, HeadCoverage: 0.0484369, HeadSupport: 123439, HeadSize: 123439, Time: 1.93891 ms
#
# Rule 712: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 22703, HeadCoverage: 0.183921, HeadSupport: 123439, HeadSize: 123439, Time: 0.83712 ms
#
# Rule 713: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 123220, HeadCoverage: 0.998226, HeadSupport: 123439, HeadSize: 123439, Time: 0.031296 ms
#
# Rule 714: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 24687, HeadCoverage: 0.199994, HeadSupport: 123439, HeadSize: 123439, Time: 1.18298 ms
#
# Rule 715: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 24890, HeadCoverage: 0.201638, HeadSupport: 123439, HeadSize: 123439, Time: 0.965888 ms
#
# Rule 716: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 7161, HeadCoverage: 0.0580125, HeadSupport: 123439, HeadSize: 123439, Time: 6.53565 ms
#
# Rule 717: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?2 ) ^ ( ?1 https://w3id.org/biolink/vocab/location_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?2 ) | Support: 7882, HeadCoverage: 0.0568896, HeadSupport: 138549, HeadSize: 138549, Time: 2.36426 ms
#
# Rule 718: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_phenotype ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/location_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?2 ) | Support: 8357, HeadCoverage: 0.060318, HeadSupport: 138549, HeadSize: 138549, Time: 0.373088 ms
#
# Rule 719: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/produces ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?2 ) | Support: 15843, HeadCoverage: 0.114349, HeadSupport: 138549, HeadSize: 138549, Time: 3.26323 ms
#
# Rule 720: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/produces ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?2 ) | Support: 21267, HeadCoverage: 0.153498, HeadSupport: 138549, HeadSize: 138549, Time: 0.927168 ms
#
# Rule 721: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/produces ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?2 ) | Support: 1953, HeadCoverage: 0.0140961, HeadSupport: 138549, HeadSize: 138549, Time: 3.93216 ms
#
# Rule 722: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 4504, HeadCoverage: 0.0325084, HeadSupport: 138549, HeadSize: 138549, Time: 0.055232 ms
#
# Rule 723: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_input ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 2822, HeadCoverage: 0.0228615, HeadSupport: 123439, HeadSize: 123439, Time: 636.119 ms
#
# Rule 724: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_input ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 3569, HeadCoverage: 0.0289131, HeadSupport: 123439, HeadSize: 123439, Time: 636.861 ms
#
# Rule 725: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/related_to ?2 ) | Support: 90348, HeadCoverage: 0.7721, HeadSupport: 117016, HeadSize: 117016, Time: 0.311008 ms
#
# Rule 726: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 105006, HeadCoverage: 0.889278, HeadSupport: 118080, HeadSize: 118080, Time: 32.678 ms
#
# Rule 727: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 52644, HeadCoverage: 0.445833, HeadSupport: 118080, HeadSize: 118080, Time: 20.9506 ms
#
# Rule 728: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 70524, HeadCoverage: 0.597256, HeadSupport: 118080, HeadSize: 118080, Time: 480.512 ms
#
# Rule 729: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/capable_of ?2 ) | Support: 10517, HeadCoverage: 0.0890667, HeadSupport: 118080, HeadSize: 118080, Time: 0.28368 ms
#
# Rule 730: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_participant ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 3890, HeadCoverage: 0.0315135, HeadSupport: 123439, HeadSize: 123439, Time: 1314.84 ms
#
# Rule 731: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_part ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 119942, HeadCoverage: 0.97167, HeadSupport: 123439, HeadSize: 123439, Time: 94.924 ms
#
# Rule 732: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_part ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 91103, HeadCoverage: 0.738041, HeadSupport: 123439, HeadSize: 123439, Time: 7.83334 ms
#
# Rule 733: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 13333, HeadCoverage: 0.108013, HeadSupport: 123439, HeadSize: 123439, Time: 241.994 ms
#
# Rule 734: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 2650, HeadCoverage: 0.0214681, HeadSupport: 123439, HeadSize: 123439, Time: 26.5562 ms
#
# Rule 735: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_output ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 3569, HeadCoverage: 0.0289131, HeadSupport: 123439, HeadSize: 123439, Time: 636.161 ms
#
# Rule 736: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_output ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_part ?2 ) | Support: 2822, HeadCoverage: 0.0228615, HeadSupport: 123439, HeadSize: 123439, Time: 632.16 ms
#
# === Timing summary ===
# Indexing time:          24415.5 ms
# CSR build+upload time:  1655.93 ms
# Rule parsing time:      389.678 ms
# Support counting time:  37493.8 ms
# Total time:             63955.2 ms
# Warp-coop rules:        226  (threshold maxfan > 64)
#
# === Per-rule statistics (736 rules) ===
# Average: 18.7821 ms
# Median:  0.320512 ms
# Std Dev: 82.6485 ms
# Min:     0.006176 ms
# Max:     1314.84 ms
# P95:     62.3884 ms
#
# === Statistics by body size ===
# Body size 1 (9 rules): avg=0.0334684 ms, median=0.028448 ms, min=0.021248 ms, max=0.067232 ms, P95=0.067232 ms
# Body size 2 (96 rules): avg=3.33266 ms, median=0.065664 ms, min=0.010208 ms, max=77.7073 ms, P95=25.2867 ms
# Body size 3 (631 rules): avg=21.4 ms, median=0.462848 ms, min=0.006176 ms, max=1314.84 ms, P95=86.0654 ms

# %%
# !./bench_gpu ../test_data/original_train.ttl ../test_data/rules_300minutes.txt
# Out:
# === Index built ===
# Triples (deduped): 6794977
# Unique RDF terms: 3164825
# Predicates: 26
# Entity count: 3164825
# CSR index built: 26 predicates  (1449 ms)
#
# === Rules loaded ===
# Rule count: 931
#
#
# Rule 1: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0.049152 ms
#
# Rule 2: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?1 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 11516, HeadCoverage: 0.093293, HeadSupport: 123439, HeadSize: 123439, Time: 0.028448 ms
#
# Rule 3: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 0.016384 ms
#
# Rule 4: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 5082, HeadCoverage: 0.0636348, HeadSupport: 79862, HeadSize: 79862, Time: 0.018432 ms
#
# Rule 5: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) => ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 4504, HeadCoverage: 0.0381436, HeadSupport: 118080, HeadSize: 118080, Time: 0.022528 ms
#
# Rule 6: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 22917, HeadCoverage: 0.19408, HeadSupport: 118080, HeadSize: 118080, Time: 0.018624 ms
#
# Rule 7: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 4504, HeadCoverage: 0.0325084, HeadSupport: 138549, HeadSize: 138549, Time: 0.024992 ms
#
# Rule 8: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?1 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 21732, HeadCoverage: 0.185718, HeadSupport: 117016, HeadSize: 117016, Time: 0.024544 ms
#
# Rule 9: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 22917, HeadCoverage: 0.193508, HeadSupport: 118429, HeadSize: 118429, Time: 0.022336 ms
#
# Rule 10: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?1 ) | Support: 106, HeadCoverage: 0.946429, HeadSupport: 112, HeadSize: 112, Time: 0.038912 ms
#
# Rule 11: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) | Support: 98, HeadCoverage: 0.875, HeadSupport: 112, HeadSize: 112, Time: 0.030176 ms
#
# Rule 12: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) | Support: 213, HeadCoverage: 1, HeadSupport: 213, HeadSize: 213, Time: 0.008992 ms
#
# Rule 13: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) | Support: 9, HeadCoverage: 0.0422535, HeadSupport: 213, HeadSize: 213, Time: 0.0088 ms
#
# Rule 14: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?2 ) => ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) | Support: 9, HeadCoverage: 0.0422535, HeadSupport: 213, HeadSize: 213, Time: 0.008864 ms
#
# Rule 15: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 0.01232 ms
#
# Rule 16: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 68, HeadCoverage: 0.0640301, HeadSupport: 1062, HeadSize: 1062, Time: 0.02048 ms
#
# Rule 17: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 0.027392 ms
#
# Rule 18: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 209, HeadCoverage: 0.196798, HeadSupport: 1062, HeadSize: 1062, Time: 0.023008 ms
#
# Rule 19: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 15, HeadCoverage: 0.0141243, HeadSupport: 1062, HeadSize: 1062, Time: 0.342432 ms
#
# Rule 20: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0.01024 ms
#
# Rule 21: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 62, HeadCoverage: 0.0583804, HeadSupport: 1062, HeadSize: 1062, Time: 0.01632 ms
#
# Rule 22: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 263, HeadCoverage: 0.247646, HeadSupport: 1062, HeadSize: 1062, Time: 0.29696 ms
#
# Rule 23: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 0.020416 ms
#
# Rule 24: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 0.02032 ms
#
# Rule 25: ( ?0 https://w3id.org/biolink/vocab/assesses ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/capable_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) | Support: 94, HeadCoverage: 0.839286, HeadSupport: 112, HeadSize: 112, Time: 0.053664 ms
#
# Rule 26: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/produces ?1 ) | Support: 217, HeadCoverage: 0.0621242, HeadSupport: 3493, HeadSize: 3493, Time: 0.010368 ms
#
# Rule 27: ( ?0 https://w3id.org/biolink/vocab/enabled_by ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?1 ) | Support: 423, HeadCoverage: 0.0553955, HeadSupport: 7636, HeadSize: 7636, Time: 0.02048 ms
#
# Rule 28: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/enables ?1 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?0 ) | Support: 3747, HeadCoverage: 0.490702, HeadSupport: 7636, HeadSize: 7636, Time: 0.011744 ms
#
# Rule 29: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/produces ?1 ) | Support: 162, HeadCoverage: 0.0463785, HeadSupport: 3493, HeadSize: 3493, Time: 0.200384 ms
#
# Rule 30: ( ?0 https://w3id.org/biolink/vocab/enabled_by ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/enabled_by ?1 ) | Support: 209, HeadCoverage: 0.0273704, HeadSupport: 7636, HeadSize: 7636, Time: 0.021824 ms
#
# Rule 31: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?0 ) | Support: 624, HeadCoverage: 0.0240462, HeadSupport: 25950, HeadSize: 25950, Time: 0.017216 ms
#
# Rule 32: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?1 ) | Support: 6833, HeadCoverage: 0.263314, HeadSupport: 25950, HeadSize: 25950, Time: 0.017248 ms
#
# Rule 33: ( ?0 https://w3id.org/biolink/vocab/location_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/location_of ?1 ) | Support: 1279, HeadCoverage: 0.0492871, HeadSupport: 25950, HeadSize: 25950, Time: 3.1503 ms
#
# Rule 34: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) | Support: 3102, HeadCoverage: 0.0933353, HeadSupport: 33235, HeadSize: 33235, Time: 0.094464 ms
#
# Rule 35: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) | Support: 995, HeadCoverage: 0.0299383, HeadSupport: 33235, HeadSize: 33235, Time: 0.080096 ms
#
# Rule 36: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 15054, HeadCoverage: 0.298946, HeadSupport: 50357, HeadSize: 50357, Time: 0.0176 ms
#
# Rule 37: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?1 ) | Support: 1528, HeadCoverage: 0.0459756, HeadSupport: 33235, HeadSize: 33235, Time: 0.016384 ms
#
# Rule 38: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/occurs_in ?2 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 13229, HeadCoverage: 0.262704, HeadSupport: 50357, HeadSize: 50357, Time: 0.155712 ms
#
# Rule 39: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/occurs_in ?1 ) | Support: 1347, HeadCoverage: 0.0405296, HeadSupport: 33235, HeadSize: 33235, Time: 1.57901 ms
#
# Rule 40: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 123439, HeadCoverage: 1, HeadSupport: 123439, HeadSize: 123439, Time: 0.03072 ms
#
# Rule 41: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?0 ) | Support: 1322, HeadCoverage: 0.0165536, HeadSupport: 79862, HeadSize: 79862, Time: 0.038912 ms
#
# Rule 42: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_output ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 1341, HeadCoverage: 0.0167915, HeadSupport: 79862, HeadSize: 79862, Time: 0.033152 ms
#
# Rule 43: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 3609, HeadCoverage: 0.0451905, HeadSupport: 79862, HeadSize: 79862, Time: 13.2014 ms
#
# Rule 44: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/enabled_by ?0 ) => ( ?2 https://w3id.org/biolink/vocab/enables ?1 ) | Support: 3738, HeadCoverage: 0.841323, HeadSupport: 4443, HeadSize: 4443, Time: 0.023744 ms
#
# Rule 45: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/enables ?0 ) | Support: 4439, HeadCoverage: 0.9991, HeadSupport: 4443, HeadSize: 4443, Time: 0.012288 ms
#
# Rule 46: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 12185, HeadCoverage: 0.152576, HeadSupport: 79862, HeadSize: 79862, Time: 0.020768 ms
#
# Rule 47: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) | Support: 79862, HeadCoverage: 1, HeadSupport: 79862, HeadSize: 79862, Time: 0.022528 ms
#
# Rule 48: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_part ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 11506, HeadCoverage: 0.093212, HeadSupport: 123439, HeadSize: 123439, Time: 0.427936 ms
#
# Rule 49: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_part ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) | Support: 76407, HeadCoverage: 0.618986, HeadSupport: 123439, HeadSize: 123439, Time: 16.3931 ms
#
# Rule 50: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 3609, HeadCoverage: 0.0451905, HeadSupport: 79862, HeadSize: 79862, Time: 12.9952 ms
#
# Rule 51: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?0 ) | Support: 1322, HeadCoverage: 0.0165536, HeadSupport: 79862, HeadSize: 79862, Time: 0.038944 ms
#
# Rule 52: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 1341, HeadCoverage: 0.0167915, HeadSupport: 79862, HeadSize: 79862, Time: 0.033504 ms
#
# Rule 53: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 12185, HeadCoverage: 0.152576, HeadSupport: 79862, HeadSize: 79862, Time: 0.020416 ms
#
# Rule 54: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) | Support: 79862, HeadCoverage: 1, HeadSupport: 79862, HeadSize: 79862, Time: 0.02224 ms
#
# Rule 55: ( ?0 https://w3id.org/biolink/vocab/is_assessed_by ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/assesses ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?0 ) | Support: 13764, HeadCoverage: 0.116565, HeadSupport: 118080, HeadSize: 118080, Time: 0.093184 ms
#
# Rule 56: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 1939, HeadCoverage: 0.0164211, HeadSupport: 118080, HeadSize: 118080, Time: 0.022528 ms
#
# Rule 57: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 8623, HeadCoverage: 0.0730268, HeadSupport: 118080, HeadSize: 118080, Time: 0.022368 ms
#
# Rule 58: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) | Support: 24973, HeadCoverage: 0.20231, HeadSupport: 123439, HeadSize: 123439, Time: 0.197984 ms
#
# Rule 59: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_part ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_part ?1 ) | Support: 106048, HeadCoverage: 0.859113, HeadSupport: 123439, HeadSize: 123439, Time: 0.461056 ms
#
# Rule 60: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 1206, HeadCoverage: 0.0102134, HeadSupport: 118080, HeadSize: 118080, Time: 5.33242 ms
#
# Rule 61: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 3552, HeadCoverage: 0.0300813, HeadSupport: 118080, HeadSize: 118080, Time: 21.5788 ms
#
# Rule 62: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 5320, HeadCoverage: 0.0450542, HeadSupport: 118080, HeadSize: 118080, Time: 4.4456 ms
#
# Rule 63: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) | Support: 1978, HeadCoverage: 0.0167514, HeadSupport: 118080, HeadSize: 118080, Time: 0.29888 ms
#
# Rule 64: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/capable_of ?0 ) | Support: 2994, HeadCoverage: 0.0253557, HeadSupport: 118080, HeadSize: 118080, Time: 0.196224 ms
#
# Rule 65: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 12031, HeadCoverage: 0.0868357, HeadSupport: 138549, HeadSize: 138549, Time: 0.027872 ms
#
# Rule 66: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_phenotype ?1 ) | Support: 3626, HeadCoverage: 0.0261712, HeadSupport: 138549, HeadSize: 138549, Time: 45.745 ms
#
# Rule 67: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 3613, HeadCoverage: 0.0308761, HeadSupport: 117016, HeadSize: 117016, Time: 5.50797 ms
#
# Rule 68: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 8635, HeadCoverage: 0.0737933, HeadSupport: 117016, HeadSize: 117016, Time: 0.062848 ms
#
# Rule 69: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 6844, HeadCoverage: 0.0584877, HeadSupport: 117016, HeadSize: 117016, Time: 0.059072 ms
#
# Rule 70: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 7450, HeadCoverage: 0.0636665, HeadSupport: 117016, HeadSize: 117016, Time: 5.25395 ms
#
# Rule 71: ( ?0 https://w3id.org/biolink/vocab/enables ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/enabled_by ?2 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 3744, HeadCoverage: 0.0319956, HeadSupport: 117016, HeadSize: 117016, Time: 0.022528 ms
#
# Rule 72: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 110638, HeadCoverage: 0.945495, HeadSupport: 117016, HeadSize: 117016, Time: 0.029216 ms
#
# Rule 73: ( ?0 https://w3id.org/biolink/vocab/synonym ?1 ) ^ ( ?2 http://www.w3.org/2000/01/rdf-schema#label ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 2459, HeadCoverage: 0.0210142, HeadSupport: 117016, HeadSize: 117016, Time: 0.039616 ms
#
# Rule 74: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) | Support: 6976, HeadCoverage: 0.0596158, HeadSupport: 117016, HeadSize: 117016, Time: 0.0512 ms
#
# Rule 75: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 10897, HeadCoverage: 0.093124, HeadSupport: 117016, HeadSize: 117016, Time: 0.043776 ms
#
# Rule 76: ( ?0 http://www.w3.org/2000/01/rdf-schema#label ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/synonym ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 2442, HeadCoverage: 0.0208689, HeadSupport: 117016, HeadSize: 117016, Time: 0.036864 ms
#
# Rule 77: ( ?0 https://w3id.org/biolink/vocab/synonym ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/synonym ?1 ) => ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) | Support: 2331, HeadCoverage: 0.0199204, HeadSupport: 117016, HeadSize: 117016, Time: 0.316864 ms
#
# Rule 78: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?1 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) | Support: 4110, HeadCoverage: 0.0816173, HeadSupport: 50357, HeadSize: 50357, Time: 0.019872 ms
#
# Rule 79: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) => ( ?2 https://w3id.org/biolink/vocab/assesses ?1 ) | Support: 3364, HeadCoverage: 0.066803, HeadSupport: 50357, HeadSize: 50357, Time: 1.1759 ms
#
# Rule 80: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/assesses ?2 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 11972, HeadCoverage: 0.10109, HeadSupport: 118429, HeadSize: 118429, Time: 0.11264 ms
#
# Rule 81: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/occurs_in ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 2582, HeadCoverage: 0.0218021, HeadSupport: 118429, HeadSize: 118429, Time: 0.063968 ms
#
# Rule 82: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 5348, HeadCoverage: 0.0451579, HeadSupport: 118429, HeadSize: 118429, Time: 0.020416 ms
#
# Rule 83: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 3554, HeadCoverage: 0.0300095, HeadSupport: 118429, HeadSize: 118429, Time: 0.01712 ms
#
# Rule 84: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 2818, HeadCoverage: 0.0237948, HeadSupport: 118429, HeadSize: 118429, Time: 14.0373 ms
#
# Rule 85: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 1997, HeadCoverage: 0.0168624, HeadSupport: 118429, HeadSize: 118429, Time: 0.04192 ms
#
# Rule 86: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/capable_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 2973, HeadCoverage: 0.0251036, HeadSupport: 118429, HeadSize: 118429, Time: 0.1024 ms
#
# Rule 87: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 77321, HeadCoverage: 0.5, HeadSupport: 154642, HeadSize: 154642, Time: 18.9993 ms
#
# Rule 88: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 77321, HeadCoverage: 0.5, HeadSupport: 154642, HeadSize: 154642, Time: 19.0196 ms
#
# Rule 89: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 80893, HeadCoverage: 0.523099, HeadSupport: 154642, HeadSize: 154642, Time: 30.9883 ms
#
# Rule 90: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 1794, HeadCoverage: 0.0151483, HeadSupport: 118429, HeadSize: 118429, Time: 0.08192 ms
#
# Rule 91: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) | Support: 1904, HeadCoverage: 0.0160771, HeadSupport: 118429, HeadSize: 118429, Time: 0.034816 ms
#
# Rule 92: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 1872, HeadCoverage: 0.0158069, HeadSupport: 118429, HeadSize: 118429, Time: 0.289728 ms
#
# Rule 93: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?2 https://w3id.org/biolink/vocab/consumes ?1 ) | Support: 1688, HeadCoverage: 0.0142533, HeadSupport: 118429, HeadSize: 118429, Time: 0.301504 ms
#
# Rule 94: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 89519, HeadCoverage: 0.578879, HeadSupport: 154642, HeadSize: 154642, Time: 0.026944 ms
#
# Rule 95: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?0 ) | Support: 2674, HeadCoverage: 0.0172916, HeadSupport: 154642, HeadSize: 154642, Time: 0.056992 ms
#
# Rule 96: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) | Support: 2704, HeadCoverage: 0.0174855, HeadSupport: 154642, HeadSize: 154642, Time: 0.050944 ms
#
# Rule 97: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 34028, HeadCoverage: 0.0258071, HeadSupport: 1318552, HeadSize: 1318552, Time: 1.18547 ms
#
# Rule 98: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 67852, HeadCoverage: 0.0514595, HeadSupport: 1318552, HeadSize: 1318552, Time: 0.115008 ms
#
# Rule 99: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 118994, HeadCoverage: 0.090246, HeadSupport: 1318552, HeadSize: 1318552, Time: 1.3312 ms
#
# Rule 100: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) | Support: 1259536, HeadCoverage: 0.955242, HeadSupport: 1318552, HeadSize: 1318552, Time: 0.190464 ms
#
# Rule 101: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) | Support: 13848, HeadCoverage: 0.0100067, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.135168 ms
#
# Rule 102: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_input ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 32820, HeadCoverage: 0.023716, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.095008 ms
#
# Rule 103: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_output ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 32820, HeadCoverage: 0.023716, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.095552 ms
#
# Rule 104: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 24754, HeadCoverage: 0.0178875, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.086624 ms
#
# Rule 105: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) | Support: 1375885, HeadCoverage: 0.994228, HeadSupport: 1383873, HeadSize: 1383873, Time: 0.163456 ms
#
# Rule 106: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/occurs_in ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/enabled_by ?3 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 11, HeadCoverage: 0.0982143, HeadSupport: 112, HeadSize: 112, Time: 0.059168 ms
#
# Rule 107: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 21, HeadCoverage: 0.1875, HeadSupport: 112, HeadSize: 112, Time: 0.777216 ms
#
# Rule 108: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?0 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 3, HeadCoverage: 0.0267857, HeadSupport: 112, HeadSize: 112, Time: 0.824768 ms
#
# Rule 109: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 95, HeadCoverage: 0.848214, HeadSupport: 112, HeadSize: 112, Time: 0.013856 ms
#
# Rule 110: ( ?0 https://w3id.org/biolink/vocab/occurs_in ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/occurs_in ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?1 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 78, HeadCoverage: 0.696429, HeadSupport: 112, HeadSize: 112, Time: 0.021824 ms
#
# Rule 111: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 20, HeadCoverage: 0.0938967, HeadSupport: 213, HeadSize: 213, Time: 0.026816 ms
#
# Rule 112: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 95, HeadCoverage: 0.446009, HeadSupport: 213, HeadSize: 213, Time: 0.008576 ms
#
# Rule 113: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 53, HeadCoverage: 0.248826, HeadSupport: 213, HeadSize: 213, Time: 0.009696 ms
#
# Rule 114: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?0 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 43, HeadCoverage: 0.201878, HeadSupport: 213, HeadSize: 213, Time: 0.008192 ms
#
# Rule 115: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 40, HeadCoverage: 0.187793, HeadSupport: 213, HeadSize: 213, Time: 0.007104 ms
#
# Rule 116: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 170, HeadCoverage: 0.798122, HeadSupport: 213, HeadSize: 213, Time: 0.008192 ms
#
# Rule 117: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 20, HeadCoverage: 0.0938967, HeadSupport: 213, HeadSize: 213, Time: 0.008192 ms
#
# Rule 118: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/inverseOf ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 5, HeadCoverage: 0.0234742, HeadSupport: 213, HeadSize: 213, Time: 0.007968 ms
#
# Rule 119: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subPropertyOf ?0 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 154, HeadCoverage: 0.723005, HeadSupport: 213, HeadSize: 213, Time: 0.007296 ms
#
# Rule 120: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/inverseOf ?0 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 46, HeadCoverage: 0.215962, HeadSupport: 213, HeadSize: 213, Time: 0.006368 ms
#
# Rule 121: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/inverseOf ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 5, HeadCoverage: 0.0234742, HeadSupport: 213, HeadSize: 213, Time: 0.006688 ms
#
# Rule 122: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/inverseOf ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 20, HeadCoverage: 0.0938967, HeadSupport: 213, HeadSize: 213, Time: 0.007136 ms
#
# Rule 123: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/inverseOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 49, HeadCoverage: 0.230047, HeadSupport: 213, HeadSize: 213, Time: 0.006144 ms
#
# Rule 124: ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 39, HeadCoverage: 0.183099, HeadSupport: 213, HeadSize: 213, Time: 0.026624 ms
#
# Rule 125: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subPropertyOf ?3 ) => ( ?3 https://w3id.org/biolink/vocab/subPropertyOf ?2 ) | Support: 102, HeadCoverage: 0.478873, HeadSupport: 213, HeadSize: 213, Time: 0.007968 ms
#
# Rule 126: ( ?0 https://w3id.org/biolink/vocab/assesses ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/assesses ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?0 ) => ( ?3 https://w3id.org/biolink/vocab/is_assessed_by ?2 ) | Support: 76, HeadCoverage: 0.678571, HeadSupport: 112, HeadSize: 112, Time: 1.89955 ms
#
# Rule 127: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 11, HeadCoverage: 0.0103578, HeadSupport: 1062, HeadSize: 1062, Time: 0.07776 ms
#
# Rule 128: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 27, HeadCoverage: 0.0254237, HeadSupport: 1062, HeadSize: 1062, Time: 0.095424 ms
#
# Rule 129: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 37, HeadCoverage: 0.0348399, HeadSupport: 1062, HeadSize: 1062, Time: 0.064448 ms
#
# Rule 130: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 29, HeadCoverage: 0.027307, HeadSupport: 1062, HeadSize: 1062, Time: 0.017088 ms
#
# Rule 131: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 135, HeadCoverage: 0.127119, HeadSupport: 1062, HeadSize: 1062, Time: 0.022944 ms
#
# Rule 132: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 68, HeadCoverage: 0.0640301, HeadSupport: 1062, HeadSize: 1062, Time: 0.01408 ms
#
# Rule 133: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 236, HeadCoverage: 0.222222, HeadSupport: 1062, HeadSize: 1062, Time: 0.02736 ms
#
# Rule 134: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 18, HeadCoverage: 0.0169492, HeadSupport: 1062, HeadSize: 1062, Time: 0.022528 ms
#
# Rule 135: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 1016, HeadCoverage: 0.956685, HeadSupport: 1062, HeadSize: 1062, Time: 0.01136 ms
#
# Rule 136: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 11, HeadCoverage: 0.0103578, HeadSupport: 1062, HeadSize: 1062, Time: 0.024576 ms
#
# Rule 137: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 37, HeadCoverage: 0.0348399, HeadSupport: 1062, HeadSize: 1062, Time: 0.030432 ms
#
# Rule 138: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 41, HeadCoverage: 0.0386064, HeadSupport: 1062, HeadSize: 1062, Time: 0.048864 ms
#
# Rule 139: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.41728 ms
#
# Rule 140: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 691, HeadCoverage: 0.650659, HeadSupport: 1062, HeadSize: 1062, Time: 0.297408 ms
#
# Rule 141: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 27, HeadCoverage: 0.0254237, HeadSupport: 1062, HeadSize: 1062, Time: 0.03552 ms
#
# Rule 142: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 226, HeadCoverage: 0.212806, HeadSupport: 1062, HeadSize: 1062, Time: 0.008256 ms
#
# Rule 143: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?1 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 41, HeadCoverage: 0.0386064, HeadSupport: 1062, HeadSize: 1062, Time: 1.00112 ms
#
# Rule 144: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 28, HeadCoverage: 0.0263653, HeadSupport: 1062, HeadSize: 1062, Time: 1.71606 ms
#
# Rule 145: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 385, HeadCoverage: 0.362524, HeadSupport: 1062, HeadSize: 1062, Time: 0.012672 ms
#
# Rule 146: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?0 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 1062, HeadCoverage: 1, HeadSupport: 1062, HeadSize: 1062, Time: 0.008192 ms
#
# Rule 147: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 960, HeadCoverage: 0.903955, HeadSupport: 1062, HeadSize: 1062, Time: 0.009888 ms
#
# Rule 148: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/subclass_of ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 21, HeadCoverage: 0.019774, HeadSupport: 1062, HeadSize: 1062, Time: 0.05136 ms
#
# Rule 149: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 62, HeadCoverage: 0.0583804, HeadSupport: 1062, HeadSize: 1062, Time: 0.01648 ms
#
# Rule 150: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 61, HeadCoverage: 0.0574388, HeadSupport: 1062, HeadSize: 1062, Time: 4.39091 ms
#
# Rule 151: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 779, HeadCoverage: 0.733522, HeadSupport: 1062, HeadSize: 1062, Time: 0.016384 ms
#
# Rule 152: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 1053, HeadCoverage: 0.991525, HeadSupport: 1062, HeadSize: 1062, Time: 0.01024 ms
#
# Rule 153: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) | Support: 17, HeadCoverage: 0.0160075, HeadSupport: 1062, HeadSize: 1062, Time: 0.022528 ms
#
# Rule 154: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?0 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 0.022272 ms
#
# Rule 155: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 236, HeadCoverage: 0.222222, HeadSupport: 1062, HeadSize: 1062, Time: 0.022528 ms
#
# Rule 156: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.445824 ms
#
# Rule 157: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 874, HeadCoverage: 0.822976, HeadSupport: 1062, HeadSize: 1062, Time: 9.71808 ms
#
# Rule 158: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 101, HeadCoverage: 0.0951036, HeadSupport: 1062, HeadSize: 1062, Time: 0.044864 ms
#
# Rule 159: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/related_to ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 27, HeadCoverage: 0.0254237, HeadSupport: 1062, HeadSize: 1062, Time: 54.8915 ms
#
# Rule 160: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 914, HeadCoverage: 0.86064, HeadSupport: 1062, HeadSize: 1062, Time: 0.01888 ms
#
# Rule 161: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 27, HeadCoverage: 0.0254237, HeadSupport: 1062, HeadSize: 1062, Time: 0.06144 ms
#
# Rule 162: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 222, HeadCoverage: 0.20904, HeadSupport: 1062, HeadSize: 1062, Time: 0.354336 ms
#
# Rule 163: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 16, HeadCoverage: 0.0150659, HeadSupport: 1062, HeadSize: 1062, Time: 0.028672 ms
#
# Rule 164: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.39136 ms
#
# Rule 165: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_chemical_role ?2 ) | Support: 664, HeadCoverage: 0.625235, HeadSupport: 1062, HeadSize: 1062, Time: 0.165056 ms
#
# ...
#
# Rule 886: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_output ?2 ) ^ ( ?1 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 3572, HeadCoverage: 0.0230985, HeadSupport: 154642, HeadSize: 154642, Time: 43.2114 ms
#
# Rule 887: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 13164, HeadCoverage: 0.111155, HeadSupport: 118429, HeadSize: 118429, Time: 1.43632 ms
#
# Rule 888: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 3329, HeadCoverage: 0.0281097, HeadSupport: 118429, HeadSize: 118429, Time: 1.55155 ms
#
# Rule 889: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/produces ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 5083, HeadCoverage: 0.0429202, HeadSupport: 118429, HeadSize: 118429, Time: 3.2297 ms
#
# Rule 890: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 39112, HeadCoverage: 0.330257, HeadSupport: 118429, HeadSize: 118429, Time: 0.615936 ms
#
# Rule 891: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 117795, HeadCoverage: 0.994647, HeadSupport: 118429, HeadSize: 118429, Time: 0.027584 ms
#
# Rule 892: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_participant ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 13111, HeadCoverage: 0.110708, HeadSupport: 118429, HeadSize: 118429, Time: 39.1532 ms
#
# Rule 893: ( ?0 https://w3id.org/biolink/vocab/synonym ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/synonym ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 4334, HeadCoverage: 0.0365958, HeadSupport: 118429, HeadSize: 118429, Time: 2.7945 ms
#
# Rule 894: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 79084, HeadCoverage: 0.667776, HeadSupport: 118429, HeadSize: 118429, Time: 0.559808 ms
#
# Rule 895: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?0 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 81626, HeadCoverage: 0.68924, HeadSupport: 118429, HeadSize: 118429, Time: 0.482912 ms
#
# Rule 896: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_part ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 59688, HeadCoverage: 0.503998, HeadSupport: 118429, HeadSize: 118429, Time: 83.9832 ms
#
# Rule 897: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 1565, HeadCoverage: 0.0101201, HeadSupport: 154642, HeadSize: 154642, Time: 0.085888 ms
#
# Rule 898: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_input ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 89519, HeadCoverage: 0.578879, HeadSupport: 154642, HeadSize: 154642, Time: 51.0341 ms
#
# Rule 899: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_output ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 89519, HeadCoverage: 0.578879, HeadSupport: 154642, HeadSize: 154642, Time: 50.4243 ms
#
# Rule 900: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 8205, HeadCoverage: 0.053058, HeadSupport: 154642, HeadSize: 154642, Time: 0.079872 ms
#
# Rule 901: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 1626, HeadCoverage: 0.0105146, HeadSupport: 154642, HeadSize: 154642, Time: 0.075904 ms
#
# Rule 902: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 98076, HeadCoverage: 0.828142, HeadSupport: 118429, HeadSize: 118429, Time: 169.086 ms
#
# Rule 903: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_phenotype ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 117903, HeadCoverage: 0.995559, HeadSupport: 118429, HeadSize: 118429, Time: 1.46698 ms
#
# Rule 904: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 5018, HeadCoverage: 0.0324491, HeadSupport: 154642, HeadSize: 154642, Time: 0.165664 ms
#
# Rule 905: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 15558, HeadCoverage: 0.100607, HeadSupport: 154642, HeadSize: 154642, Time: 0.08816 ms
#
# Rule 906: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/related_to ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 4356, HeadCoverage: 0.0281683, HeadSupport: 154642, HeadSize: 154642, Time: 0.38032 ms
#
# Rule 907: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_participant ?2 ) ^ ( ?0 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 15898, HeadCoverage: 0.102805, HeadSupport: 154642, HeadSize: 154642, Time: 153.273 ms
#
# Rule 908: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_participant ?2 ) ^ ( ?1 https://w3id.org/biolink/vocab/subclass_of ?3 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 4065, HeadCoverage: 0.0262865, HeadSupport: 154642, HeadSize: 154642, Time: 77.3202 ms
#
# Rule 909: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?1 https://w3id.org/biolink/vocab/has_participant ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 15379, HeadCoverage: 0.0994491, HeadSupport: 154642, HeadSize: 154642, Time: 0.04288 ms
#
# Rule 910: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_participant ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/subclass_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 26990, HeadCoverage: 0.174532, HeadSupport: 154642, HeadSize: 154642, Time: 99.8844 ms
#
# Rule 911: ( ?0 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/subclass_of ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 31030, HeadCoverage: 0.200657, HeadSupport: 154642, HeadSize: 154642, Time: 0.172032 ms
#
# Rule 912: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 62162, HeadCoverage: 0.524888, HeadSupport: 118429, HeadSize: 118429, Time: 481.763 ms
#
# Rule 913: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 59512, HeadCoverage: 0.502512, HeadSupport: 118429, HeadSize: 118429, Time: 178.055 ms
#
# Rule 914: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/capable_of ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 8683, HeadCoverage: 0.0733182, HeadSupport: 118429, HeadSize: 118429, Time: 3.07933 ms
#
# Rule 915: ( ?0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 154024, HeadCoverage: 0.996004, HeadSupport: 154642, HeadSize: 154642, Time: 0.032256 ms
#
# Rule 916: ( ?0 https://w3id.org/biolink/vocab/has_chemical_role ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 32550, HeadCoverage: 0.210486, HeadSupport: 154642, HeadSize: 154642, Time: 0.103776 ms
#
# Rule 917: ( ?0 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?2 https://w3id.org/biolink/vocab/related_to ?1 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?0 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 72966, HeadCoverage: 0.471838, HeadSupport: 154642, HeadSize: 154642, Time: 0.212992 ms
#
# Rule 918: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 5970, HeadCoverage: 0.0386053, HeadSupport: 154642, HeadSize: 154642, Time: 9.45152 ms
#
# Rule 919: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_input ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 150004, HeadCoverage: 0.970008, HeadSupport: 154642, HeadSize: 154642, Time: 69.2961 ms
#
# Rule 920: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 117598, HeadCoverage: 0.992983, HeadSupport: 118429, HeadSize: 118429, Time: 28.9748 ms
#
# Rule 921: ( ?0 https://w3id.org/biolink/vocab/consumes ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 35138, HeadCoverage: 0.296701, HeadSupport: 118429, HeadSize: 118429, Time: 32.4622 ms
#
# Rule 922: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_input ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 154030, HeadCoverage: 0.996042, HeadSupport: 154642, HeadSize: 154642, Time: 63.7358 ms
#
# Rule 923: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 115940, HeadCoverage: 0.978983, HeadSupport: 118429, HeadSize: 118429, Time: 10.71 ms
#
# Rule 924: ( ?0 https://w3id.org/biolink/vocab/capable_of ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 112628, HeadCoverage: 0.951017, HeadSupport: 118429, HeadSize: 118429, Time: 236.663 ms
#
# Rule 925: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/consumes ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 44506, HeadCoverage: 0.375803, HeadSupport: 118429, HeadSize: 118429, Time: 1.79584 ms
#
# Rule 926: ( ?0 https://w3id.org/biolink/vocab/has_phenotype ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 62093, HeadCoverage: 0.524306, HeadSupport: 118429, HeadSize: 118429, Time: 330.854 ms
#
# Rule 927: ( ?0 https://w3id.org/biolink/vocab/produces ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/consumes ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/capable_of ?1 ) => ( ?3 https://w3id.org/biolink/vocab/consumes ?2 ) | Support: 12570, HeadCoverage: 0.10614, HeadSupport: 118429, HeadSize: 118429, Time: 0.260096 ms
#
# Rule 928: ( ?0 https://w3id.org/biolink/vocab/has_participant ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_participant ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 154030, HeadCoverage: 0.996042, HeadSupport: 154642, HeadSize: 154642, Time: 57.9069 ms
#
# Rule 929: ( ?0 https://w3id.org/biolink/vocab/has_part ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_part ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 2682, HeadCoverage: 0.0173433, HeadSupport: 154642, HeadSize: 154642, Time: 52.9818 ms
#
# Rule 930: ( ?0 https://w3id.org/biolink/vocab/has_input ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_output ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 154030, HeadCoverage: 0.996042, HeadSupport: 154642, HeadSize: 154642, Time: 62.4333 ms
#
# Rule 931: ( ?0 https://w3id.org/biolink/vocab/has_output ?1 ) ^ ( ?0 https://w3id.org/biolink/vocab/has_output ?2 ) ^ ( ?3 https://w3id.org/biolink/vocab/has_participant ?1 ) => ( ?3 https://w3id.org/biolink/vocab/has_participant ?2 ) | Support: 150004, HeadCoverage: 0.970008, HeadSupport: 154642, HeadSize: 154642, Time: 67.8625 ms
#
# === Timing summary ===
# Indexing time:          21607.3 ms
# CSR build+upload time:  1448.69 ms
# Rule parsing time:      360.871 ms
# Support counting time:  19833.9 ms
# Total time:             43251 ms
# Warp-coop rules:        285  (threshold maxfan > 64)
#
# === Per-rule statistics (931 rules) ===
# Average: 21.2357 ms
# Median:  0.445824 ms
# Std Dev: 81.6747 ms
# Min:     0.006144 ms
# Max:     1310.59 ms
# P95:     96.5577 ms
#
# === Statistics by body size ===
# Body size 1 (9 rules): avg=0.0250489 ms, median=0.022528 ms, min=0.016384 ms, max=0.049152 ms, P95=0.049152 ms
# Body size 2 (96 rules): avg=2.37846 ms, median=0.052432 ms, min=0.0088 ms, max=45.745 ms, P95=18.9993 ms
# Body size 3 (826 rules): avg=23.6584 ms, median=0.694864 ms, min=0.006144 ms, max=1310.59 ms, P95=101.055 ms

# %% [markdown]
# ## Profiling (Nsight Systems)
#
# Recompiles with `-lineinfo` for better GPU kernel attribution, then runs **Nsight Systems** (`nsys`) to capture a full timeline of CUDA API calls and kernel execution.

# %%
## Step 1: Recompile with -lineinfo so nsys can map samples back to source lines
# !nvcc -O3 -lineinfo -std=c++17 bench_gpu.cu FinalRule.cpp RdfIndexes.cpp RuleParser.cpp \
    $(pkg-config --cflags --libs raptor2) -o bench_gpu_profiled

# %%
## Step 2: Run Nsight Systems profile (100-rule file for speed)
## Captures CUDA API, kernel launches, and memory transfers
# !nsys profile \
    --stats=true \
    --output=profile_gpu03 \
    --force-overwrite=true \
    ./bench_gpu_profiled \
        ../test_data/original_train.ttl \
        ../test_data/rules_150minutes_short_100rules.txt \
    2>&1 || echo "nsys not found, falling back to nvprof" && \
nvprof --print-gpu-summary \
    ./bench_gpu_profiled \
        ../test_data/original_train.ttl \
        ../test_data/rules_150minutes_short_100rules.txt \
    2>&1

# %%
## Step 3: Print Nsight Systems kernel-level statistics from the saved report
## Shows GPU kernel durations, CUDA API times, and memory transfer breakdown
# !nsys stats profile_gpu03.nsys-rep 2>&1 || echo "(nsys stats unavailable; see nsys output above)"
